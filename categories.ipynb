# %%
import pandas as pd
import numpy as np
from pydantic import BaseModel
from openai import OpenAI
import os
import json
import random
import time

# %%
# load data
data = pd.read_excel("data/intermediate/openai_results.xlsx")

# %%
# Defining the categories and their corresponding overcategories
# Daten fuer die Tabelle vorbereiten
categoories_dict = {
    "Ueberkategorie": ["Arbeitsumfeld und -ausstattung"] * 10 + ["Arbeitsorganisation und -bedingungen"] * 10 + ["Kommunikation und soziale Interaktion"] * 10 + ["Fuehrung und Unternehmenskultur"] * 10 + ["Mitarbeiterwohlbefinden und -services"] * 10,
    "Kategorie": [
        "Buerogestaltung und -ausstattung", "Technische Ausstattung und Arbeitsmittel", "Ergonomie am Arbeitsplatz", "Sauberkeit und Ordnung", "Raeumlichkeiten und Standort",
        "Laermpegel und Schallschutz", "Klimatisierung und Temperatur", "Großraumbueros und private Arbeitsbereiche", "Parkplatz, Kantine, Teekueche", "Sicherheits- und Gesundheitsmanagement",
        "Arbeitszeitgestaltung und Gleitzeit", "Homeoffice und flexible Arbeitsorte", "Urlaubsplanung und Freizeitausgleich", "Work-Life-Balance", "ueberstundenmanagement",
        "Schichtarbeit und Pausenregelungen", "Aufgabenbereich und Projekte", "Teamarbeit und Gruppenprojekte", "Selbststaendiges Arbeiten", "Herausforderungen und Abwechslungsreichtum",
        "Kommunikationsstil und -wege", "Umgangston und Arbeitsatmosphaere", "Zusammenarbeit im Team", "Feedbackkultur und Lob", "Meetings und Besprechungen",
        "Offenheit und Transparenz", "Konfliktmanagement", "Interkulturelle Zusammenarbeit", "Soziale Events und Teambuilding", "Netzwerk und Kontaktmoeglichkeiten",
        "Verhalten und Stil der Fuehrungskraefte", "Mitarbeiterfuehrung und -unterstuetzung", "Vertrauen und Respekt", "Wertschaetzung und Anerkennung", "Mitarbeiterentwicklung und -foerderung",
        "Innovationskultur und Kreativitaetsfoerderung", "Unternehmenswerte und Philosophie", "Entscheidungsfindung und Mitbestimmung", "Gerechtigkeit und Fairness", "Unternehmenskommunikation",
        "Gesundheitsfoerderung und Praevention", "Psychologische Unterstuetzung", "Arbeitszufriedenheit und Motivation", "Persoenliche Entwicklung und Weiterbildung", "Familiaere Atmosphaere und sozialer Zusammenhalt",
        "Betriebliche Sozialleistungen und Benefits", "Integration neuer Mitarbeiter", "Mitarbeiterfeedback und -befragungen", "Erreichbarkeit und Hilfsbereitschaft", "Mitarbeiterveranstaltungen und Freizeitangebote"
    ]
}

# Creating the dataframe
categoories = pd.DataFrame(categoories_dict)

categoories = categoories.reset_index(drop=True)
categoories['category_id'] = categoories.index + 1
categoories.to_excel("data/processed/categories.xlsx", index=False)

# %%
categoories
# Out:
#                            Ueberkategorie  \
# 0          Arbeitsumfeld und -ausstattung
# 1          Arbeitsumfeld und -ausstattung
# 2          Arbeitsumfeld und -ausstattung
# 3          Arbeitsumfeld und -ausstattung
# 4          Arbeitsumfeld und -ausstattung
# 5          Arbeitsumfeld und -ausstattung
# 6          Arbeitsumfeld und -ausstattung
# 7          Arbeitsumfeld und -ausstattung
# 8          Arbeitsumfeld und -ausstattung
# 9    Arbeitsorganisation und -bedingungen
# 10   Arbeitsorganisation und -bedingungen
# 11   Arbeitsorganisation und -bedingungen
# 12   Arbeitsorganisation und -bedingungen
# 13   Arbeitsorganisation und -bedingungen
# 14   Arbeitsorganisation und -bedingungen
# 15   Arbeitsorganisation und -bedingungen
# 16   Arbeitsorganisation und -bedingungen
# 17   Arbeitsorganisation und -bedingungen
# 18  Kommunikation und soziale Interaktion
# 19  Kommunikation und soziale Interaktion
# 20  Kommunikation und soziale Interaktion
# 21  Kommunikation und soziale Interaktion
# 22  Kommunikation und soziale Interaktion
# 23  Kommunikation und soziale Interaktion
# 24  Kommunikation und soziale Interaktion
# 25  Kommunikation und soziale Interaktion
# 26  Kommunikation und soziale Interaktion
# 27  Kommunikation und soziale Interaktion
# 28        Fuehrung und Unternehmenskultur
# 29        Fuehrung und Unternehmenskultur
# 30        Fuehrung und Unternehmenskultur
# 31        Fuehrung und Unternehmenskultur
# 32        Fuehrung und Unternehmenskultur
# 33        Fuehrung und Unternehmenskultur
# 34        Fuehrung und Unternehmenskultur
# 35        Fuehrung und Unternehmenskultur
# 36        Fuehrung und Unternehmenskultur
# 37        Fuehrung und Unternehmenskultur
# 38  Mitarbeiterwohlbefinden und -services
# 39  Mitarbeiterwohlbefinden und -services
# 40  Mitarbeiterwohlbefinden und -services
# 41  Mitarbeiterwohlbefinden und -services
# 42  Mitarbeiterwohlbefinden und -services
# 43  Mitarbeiterwohlbefinden und -services
# 44  Mitarbeiterwohlbefinden und -services
# 45  Mitarbeiterwohlbefinden und -services
# 46  Mitarbeiterwohlbefinden und -services
# 47  Mitarbeiterwohlbefinden und -services
#
#                                            Kategorie  category_id
# 0                   Buerogestaltung und -ausstattung            1
# 1           Technische Ausstattung und Arbeitsmittel            2
# 2                          Ergonomie am Arbeitsplatz            3
# 3                             Sauberkeit und Ordnung            4
# 4                       Raeumlichkeiten und Standort            5
# 5                        Laermpegel und Schallschutz            6
# 6                      Klimatisierung und Temperatur            7
# 7         Großraumbueros und private Arbeitsbereiche            8
# 8                      Parkplatz, Kantine, Teekueche            9
# 9                Arbeitszeitgestaltung und Gleitzeit           10
# 10               Homeoffice und flexible Arbeitsorte           11
# 11              Urlaubsplanung und Freizeitausgleich           12
# 12                                 Work-Life-Balance           13
# 13                            ueberstundenmanagement           14
# 14                      Aufgabenbereich und Projekte           15
# 15                    Teamarbeit und Gruppenprojekte           16
# 16                         Selbststaendiges Arbeiten           17
# 17        Herausforderungen und Abwechslungsreichtum           18
# 18                      Kommunikationsstil und -wege           19
# 19                                        Umgangston           20
# 20                            Zusammenarbeit im Team           21
# 21                            Feedbackkultur und Lob           22
# 22                        Meetings und Besprechungen           23
# 23                         Offenheit und Transparenz           24
# 24                                Konfliktmanagement           25
# 25                    Interkulturelle Zusammenarbeit           26
# 26                   Soziale Events und Teambuilding           27
# 27                Netzwerk und Kontaktmoeglichkeiten           28
# 28           Verhalten und Stil der Fuehrungskraefte           29
# 29           Mitarbeiterfuehrung und -unterstuetzung           30
# 30                             Vertrauen und Respekt           31
# 31                    Wertschaetzung und Anerkennung           32
# 32            Mitarbeiterentwicklung und -foerderung           33
# 33     Innovationskultur und Kreativitaetsfoerderung           34
# 34                 Unternehmenswerte und Philosophie           35
# 35            Entscheidungsfindung und Mitbestimmung           36
# 36                        Gerechtigkeit und Fairness           37
# 37                         Unternehmenskommunikation           38
# 38             Gesundheitsfoerderung und Praevention           39
# 39                     Psychologische Unterstuetzung           40
# 40               Arbeitszufriedenheit und Motivation           41
# 41        Persoenliche Entwicklung und Weiterbildung           42
# 42  Familiaere Atmosphaere und sozialer Zusammenhalt           43
# 43        Betriebliche Sozialleistungen und Benefits           44
# 44                     Integration neuer Mitarbeiter           45
# 45              Mitarbeiterfeedback und -befragungen           46
# 46              Erreichbarkeit und Hilfsbereitschaft           47
# 47   Mitarbeiterveranstaltungen und Freizeitangebote           48

# %%
# set function output format
class FindCategoryAiResponse(BaseModel):
    category: str
    category_id: int
    probability: float

    
# set openai api key
client = OpenAI(
  api_key="",  # this is also the default, it can be omitted
)

# %%
# Define a retry decorator
def retry_with_exponential_backoff(
    func,
    initial_delay: float = 1,
    exponential_base: float = 2,
    jitter: bool = True,
    max_retries: int = 10,
):
    """Retry a function with exponential backoff."""

    def wrapper(*args, **kwargs):
        num_retries = 0
        delay = initial_delay

        while True:
            try:
                return func(*args, **kwargs)

            except e:
                num_retries += 1

                if num_retries > max_retries:
                    raise Exception(f"Maximum number of retries ({max_retries}) exceeded.")

                delay *= exponential_base * (1 + jitter * random.random())

                time.sleep(delay)

            except Exception as e:
                raise e

    return wrapper

# %%
@retry_with_exponential_backoff
def call_open_ai(client: OpenAI, statement_df: pd.Series, categoories: pd.DataFrame) -> dict:
    
    row = categoories.rename(columns={'Kategorie': 'category'})
    category_json = row[['category_id', 'category']].to_json(orient='records', force_ascii=False)
    
    prompt = f""" Kategorien: {category_json} \n
    Aussage: {statement_df['value']}\n 
    key_aspect: {statement_df['key_aspect']}\n
    """
    
    # print(prompt)
    
    completion = client.chat.completions.create(
        model="gpt-3.5-turbo",
        # model="gpt-4-1106-preview",
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        functions=[
            {
            "name": "find_most_fitting_category",
            "description": """Aus den vorgegebenen Kategorien, finde die am besten passende Kategorie für die Aussage auf einer Jobportal Seite.""",
            "parameters": FindCategoryAiResponse.model_json_schema()
            }
        ],
        function_call={"name": "find_most_fitting_category"},
        temperature = 0.2,
        timeout=30,
    )

    completion_value = completion.choices[0].message.function_call.arguments
    completion_dict = json.loads(completion_value)
    completion_dict = completion_dict
    
    return completion_dict

# %%
results = []
data_df = data.copy()
data_df['category_id '] = None
data_df['category'] = ""
data_df['category_probability'] = None
category_ids = categoories['category_id'].unique()

for index, row in data_df.iterrows():
    
    # ignore missing values
    if row['value'] is np.nan:
        continue
    
    # call open ai
    result = call_open_ai(client, row, categoories)
    results.append(result)
    
    if result['category_id'] not in category_ids:
        print('Category Not found')
        continue
    
    if categoories[categoories['category_id'] == result['category_id']]['Kategorie'].values[0] != result['category']:
        print(f"{categoories[categoories['category_id'] == result['category_id']]['Kategorie'].values[0]} - {result['category']}")
    
    print(f"{index}: {row['key_aspect']} - {row['short_sumary']}")
    print(result['category'])
    print("----------")
    print()
    row['category_id '] = result['category_id']
    row['category'] = categoories[categoories['category_id'] == result['category_id']]['Kategorie'].values[0]
    row['category_probability'] = result['probability']
    data_df.loc[index] = row
    
    if index % 20 == 0:
        # result_df = pd.DataFrame(results)
        data_df.to_excel("data/processed/coded_data_3.xlsx")

data_df.to_excel("data/processed/coded_data_3.xlsx")
data_df
# Out:
# Familiaere Atmosphaere und sozialer Zusammenhalt - Atmosphäre
# 0: Atmosphäre - Herzlich, freundlich, hilfsbereit und positiv
# Atmosphäre
# ----------
#
# Category Not found
# Teamarbeit und Gruppenprojekte - Teamwork
# 2: Teamwork - Sehr hilfsbereit und auch neben dem Job trinkt man mal was zusammen.
# Teamwork
# ----------
#
# 3: Vielseitigkeit - Arbeit mit Menschen
# Herausforderungen und Abwechslungsreichtum
# ----------
#
# Category Not found
# Category Not found
# 6: Arbeitszeit - Balance zwischen Arbeit und Freizeit
# Arbeitszeitgestaltung und Gleitzeit
# ----------
#
# Category Not found
# Category Not found
# Zusammenarbeit im Team - Teamzusammenhalt
# 9: Teamzusammenhalt - Familiäres Arbeitsumfeld mit Spaß und Scherzen
# Teamzusammenhalt
# ----------
#
# Category Not found
# Category Not found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\paulr\Projects\atmospheres\categories.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>     return func(*args, **kwargs)
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a> except e:
#
# c:\Users\paulr\Projects\atmospheres\categories.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> # print(prompt)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a> completion = client.chat.completions.create(
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a>     model="gpt-3.5-turbo",
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a>     # model="gpt-4-1106-preview",
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>     messages=[
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a>         {
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a>             "role": "user",
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a>             "content": prompt,
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a>         }
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a>     ],
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=22'>23</a>     functions=[
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a>         {
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a>         "name": "find_most_fitting_category",
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a>         "description": """Aus den vorgegebenen Kategorien, finde die am besten passende Kategorie für die Aussage auf einer Jobportal Seite.""",
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=26'>27</a>         "parameters": FindCategoryAiResponse.model_json_schema()
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=27'>28</a>         }
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=28'>29</a>     ],
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=29'>30</a>     function_call={"name": "find_most_fitting_category"},
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=30'>31</a>     temperature = 0.2,
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=31'>32</a>     timeout=30,
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=32'>33</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=34'>35</a> completion_value = completion.choices[0].message.function_call.arguments
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\openai\_utils\_utils.py:299, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     298     raise TypeError(msg)
# --> 299 return func(*args, **kwargs)
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\openai\resources\chat\completions.py:594, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     592     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     593 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 594     return self._post(
#     595         "/chat/completions",
#     596         body=maybe_transform(
#     597             {
#     598                 "messages": messages,
#     599                 "model": model,
#     600                 "frequency_penalty": frequency_penalty,
#     601                 "function_call": function_call,
#     602                 "functions": functions,
#     603                 "logit_bias": logit_bias,
#     604                 "max_tokens": max_tokens,
#     605                 "n": n,
#     606                 "presence_penalty": presence_penalty,
#     607                 "response_format": response_format,
#     608                 "seed": seed,
#     609                 "stop": stop,
#     610                 "stream": stream,
#     611                 "temperature": temperature,
#     612                 "tool_choice": tool_choice,
#     613                 "tools": tools,
#     614                 "top_p": top_p,
#     615                 "user": user,
#     616             },
#     617             completion_create_params.CompletionCreateParams,
#     618         ),
#     619         options=make_request_options(
#     620             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     621         ),
#     622         cast_to=ChatCompletion,
#     623         stream=stream or False,
#     624         stream_cls=Stream[ChatCompletionChunk],
#     625     )
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\openai\_base_client.py:1055, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1052 opts = FinalRequestOptions.construct(
#    1053     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1054 )
# -> 1055 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\openai\_base_client.py:834, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     825 def request(
#     826     self,
#     827     cast_to: Type[ResponseT],
#    (...)
#     832     stream_cls: type[_StreamT] | None = None,
#     833 ) -> ResponseT | _StreamT:
# --> 834     return self._request(
#     835         cast_to=cast_to,
#     836         options=options,
#     837         stream=stream,
#     838         stream_cls=stream_cls,
#     839         remaining_retries=remaining_retries,
#     840     )
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\openai\_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpx\_transports\default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_sync\http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_sync\http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_sync\http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File c:\Users\paulr\AppData\Local\pypoetry\Cache\virtualenvs\atmospheres-WbcnL0Lo-py3.11\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File ~\.pyenv\pyenv-win\versions\3.11.2\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#
# File ~\.pyenv\pyenv-win\versions\3.11.2\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\paulr\Projects\atmospheres\categories.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>     continue
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a> # call open ai
# ---> <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a> result = call_open_ai(client, row, categoories)
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> results.append(result)
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a> if result['category_id'] not in category_ids:
#
# c:\Users\paulr\Projects\atmospheres\categories.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> try:
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>     return func(*args, **kwargs)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a> except e:
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a>     num_retries += 1
#      <a href='vscode-notebook-cell:/c%3A/Users/paulr/Projects/atmospheres/categories.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a>     if num_retries > max_retries:
#
# UnboundLocalError: cannot access local variable 'e' where it is not associated with a value

# %%
result_df = pd.DataFrame(results)
result_df.to_excel("data/openai_results.xlsx")

# %%
data
# Out:
#       Unnamed: 0                      topic  \
# 0              0          Arbeitsatmosphäre
# 1              1                  Mentoring
# 2              2          Arbeitsatmosphäre
# 3              3                   Beratung
# 4              4             Freundlichkeit
# ...          ...                        ...
# 1164        1164  Kollegen und Zusammenhalt
# 1165        1165              Arbeitsinhalt
# 1166        1166                Transparenz
# 1167        1167            Arbeitsumgebung
# 1168        1168         Arbeitsbedingungen
#
#                                            short_sumary  \
# 0         Herzlich, freundlich, hilfsbereit und positiv
# 1     Super Mentorin, die persönliche Weiterentwickl...
# 2     Sehr hilfsbereit und auch neben dem Job trinkt...
# 3                                   Arbeit mit Menschen
# 4     Die Mitarbeiter waren sehr freundlich und hilf...
# ...                                                 ...
# 1164                                Klasse Zusammenhalt
# 1165           Die Arbeit macht Spaß und ist vielseitig
# 1166                     Manchmal fehlt die Transparenz
# 1167  Systeme hängen ab und an, sonst alles top! Küc...
# 1168  Flexible Lage der Arbeitszeiten, volle Akzepta...
#
#                   key_aspect          key_word  positve  rating  assagekraft  \
# 0                 Atmosphäre          lebendig     True       9            8
# 1                  Mentoring     Unterstützung     True       9            8
# 2                   Teamwork  gemeinschaftlich     True       8            7
# 3             Vielseitigkeit              Spaß     True       8            7
# 4                Mitarbeiter        freundlich     True       8            9
# ...                      ...               ...      ...     ...          ...
# 1164          Zusammenarbeit          Kollegen     True       9            8
# 1165                workload              hoch     True       8            7
# 1166  Informationsweitergabe              spät    False       7            5
# 1167        Systemstabilität         ab und an    False       8            7
# 1168           Arbeitszeiten          flexibel     True       8            6
#
#       sarcasm_rating                                              value  \
# 0              False  Herzlich, freundlich,  hilfsbereit und voralle...
# 1              False  Ich habe einer super Mentorin , die mir die Mö...
# 2              False  Sehr hilfsbereit und auch neben dem Job trinkt...
# 3              False  Bei der Beratung steht der Mensch im Mittelpun...
# 4              False              Freundlich, konstruktiv und höflich.
# ...              ...                                                ...
# 1164           False      Die Kollegen und der Zusammenhalt ist klasse!
# 1165           False  Die Arbeit macht Spaß und ist vielseitig...es ...
# 1166           False  Allgemein gut, nur manchmal fehlt die Transpar...
# 1167           False  Systeme hängen ab und an, sonst alles top! Küc...
# 1168           False  Flexible Lage der Arbeitszeiten, volle Akzepta...
#
#       document                  column_name
# 0            1   working_atmosphere_comment
# 1            1  leadership_behavior_comment
# 2            1          team_spirit_comment
# 3            1    interesting_tasks_comment
# 4            1        communication_comment
# ...        ...                          ...
# 1164       200          team_spirit_comment
# 1165       200    interesting_tasks_comment
# 1166       200        communication_comment
# 1167       200   working_conditions_comment
# 1168       200    work_life_balance_comment
#
# [1169 rows x 12 columns]

# %%
[1, 2] + [3, 4]
# Out:
# [1, 2, 3, 4]

# %%
str(set(data[data['positve']]['topic'].to_list() + data[data['positve']]['key_aspect'].to_list()))
# Out:
# "{'Vertrauen und Wertschätzung', 'Unterstützung und Informationsfluss', 'Stellenbeschreibung', 'Vertrauen und Wohlbefinden', 'Gestaltung', 'Vorgesetzte', 'Schulungen und Weiterbildung', 'Tagesablauf', 'Erweiterungsmöglichkeiten', 'Verhalten der Chefs', 'Gleitzeit und Urlaubsanspruch', 'Umgangston und Miteinander', 'Weitergabe von Informationen', 'Zusammenarbeit mit verschiedenen Kulturen', 'Unterstützung außerhalb des Arbeitsalltags', 'Feedbackkultur', 'Urlaub und Arzttermine', 'Ausstattung und Angebote', 'Bezahlung', 'Gestaltungsmöglichkeiten und Weiterentwicklung', 'Montage', 'Rückendeckung von Beraterin und Leiterin', 'Arbeitsplatz', 'Unterhaltung', 'Interessante und vielfältige Aufgaben', 'Usability', 'Gleitzeit', 'Überstundenabbau und -ausgleich', 'Verbesserungen', 'Verständnis für Probleme', 'Schichtplanung', 'Büros/Räumlichkeiten', 'Förderung', 'Zusammenhalt im Team', 'Beziehung zwischen Arbeitern und Vorgesetzten', 'Arbeitsplatzgestaltung', 'Jugendschutzgesetz', 'Freundlichkeit und Kompetenz', 'Verständnis für wichtige Termine', 'Behandlung durch Vorgesetzte', 'Arbeitsmittel', 'Unterstützung bei Problemen', 'Freundlichkeit und Respekt', 'Arbeitsaufgaben', 'Ziele und Entscheidungsfindung', 'Transparenz', 'Heizung', 'Mischung aus Neuem und Bekanntem', 'Arbeitszeiten, Schichtmodelle, Arbeitsumfeld, Klima', 'Kundenbetrieb', 'Freizeitaktivitäten', 'Informationsversorgung', 'Anwaltstätigkeit', 'Kompetenz, Motivation, Verständnis, Humor, Erfolg', 'Interessant und vielfältig', 'Mitbestimmung des Einsatzorts', 'Gegenseitiges Vertrauen und respektvolles Miteinander', 'Platzangebot', 'Respektvolle Kommunikation von Kritik und Lob', 'Verhalten', 'Unterstützung der Mitarbeiter', 'Köln', 'Leistung und Wertschätzung', 'Unterstützung von Kollegen', 'allgemein', 'Arbeitszeit und Work-Life-Balance', 'Arbeitsplanung', 'Nett und hilfsbereit', 'Freundlichkeit und Hilfsbereitschaft des Teams', 'KCS', 'Abwechslungsreiche Aufgaben', 'Gesamterfahrung', 'Außendienst', 'Bezugspflege', 'Konfliktlösung', 'Stellenangebote', 'Arbeitszeitgestaltung', 'Aufgabenfeld', 'Qualität', 'Nettigkeit und Interesse', 'Kontakt mit DIS AG', 'betriebliches Gesundheitsmanagement', 'gutes Verhältnis', 'Schnelle Reaktionszeit', 'Empfang und Kollegen', 'Aufnahme', 'Lernmöglichkeiten', 'Arbeitszeitmodell', 'zeitliche Einteilung', 'kollegialer Zusammenhalt', 'Versorgung der Mitarbeiter', 'Arbeitsbedingungen', 'Atmosphäre', 'Abteilungen', 'Ideen und Veränderungsvorschläge', 'Motivation', 'Verpflegung', 'Umgangston und Arbeitsatmosphäre', 'Qualifikation', 'Problemlösung in der Softwareentwicklung', 'Jede Stimme zählt', 'Meister', 'Unterstützung und Förderung', 'Fragen stellen', 'Kommunikation mit Vorgesetzten und Management', 'Platz und Ausstattung', 'Teeküche und Schreibtische', 'Essen', 'Erfahrungen sammeln', 'Informationsfluss', 'Wohlfühlen', 'Respekt und Herzlichkeit', 'Einarbeitung', 'Mitarbeiterführung', 'Kassierer/in', 'Ausstattung und Einrichtung', 'Verhältnis zu Vorgesetzten', 'Liebenswürdigkeit', 'Möglichkeit, Neues zu lernen und sich weiterzuentwickeln', 'Nachtreten', 'Gesamtbewertung', 'Sauberkeit und Ordnung', 'Zeitgestaltung', 'Einsatzmöglichkeiten', 'Bank', 'Wertschätzung und Respekt', 'Bürostandort', 'Miteinander', 'Kantine', 'Stresslevel', 'Arbeitsweise', 'Ausstattung und Pflege', 'Verständigung auf Augenhöhe', 'Wertschätzung', 'Büro in Münster', 'Mitarbeiter', 'Kollegenzusammenhalt', 'Kommunikationskanäle', 'Firma', 'individuelle Wertschätzung', 'Unterstützung durch das Unternehmen', 'Umgang zwischen Kollegen und Führungskräften', nan, 'Arbeitsplatz, Parkplatz, Kantine', 'Motivation, Betreuung und faire Behandlung', 'Unternehmensentwicklung', 'Benefits', 'Kollegialität', 'Vertrauen', 'konstruktives Miteinander', 'Einrichtung', 'Kontaktfreudigkeit', 'Abwechslungsreich', 'offenes Team', 'Einblicke in Prozesse', 'Erfolg', 'Geschäftsleitung', 'Teamaktivitäten', 'Verhältnis', 'Interesse und Abwechslung', 'Arbeitsinhalt', 'Erfahrung', 'Überstundenabbau', 'Werts ...
